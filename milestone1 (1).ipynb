# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df= pd.read_csv("C:/Users/sange/Downloads/housing (1).csv")

# %%
df
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4560 non-null   float64
#  5   sqft_lot       4586 non-null   float64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4577 non-null   float64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4543 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4560.000000  4.586000e+03
# mean   5.539483e+05     3.400870     2.160815   2138.935526  1.485981e+04
# std    5.808371e+05     0.908848     0.783781    965.011449  3.592050e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.225000e+05     3.000000     1.750000   1460.000000  5.000000e+03
# 50%    4.610000e+05     3.000000     2.250000   1980.000000  7.683500e+03
# 75%    6.550000e+05     4.000000     2.500000   2620.000000  1.101850e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition    sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000   4600.000000
# mean      1.512065     0.007174     0.240652     3.451739   1840.825435
# std       0.538288     0.084404     0.778405     0.677230    970.705795
# ...

# %%
df.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living      40
# sqft_lot         14
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built         23
# yr_renovated      0
# street            0
# city             57
# statezip          0
# country           0
# dtype: int64

# %%
df["sqft_living"].unique()
# Out:
# array([ 1340.,  3650.,  1930.,  2000.,  1940.,   880.,  1350.,  2710.,
#         2430.,  1520.,  1710.,  2920.,  2330.,  1090.,  2910.,  1200.,
#         1570.,  3110.,  1370.,  1180.,  2240.,  1450.,  1750.,  2730.,
#           nan,   900.,  1650.,  1010.,  2680.,  2200.,  2530.,  2850.,
#         2280.,  1900.,  1330.,  1270.,  2170.,  2120.,  2490.,  1990.,
#         3690.,  2540.,  1800.,  2340.,  2110.,  1140.,  1480.,  1410.,
#         3180.,  2160.,  2350.,  1560.,  2740.,  1680.,  3090.,  4010.,
#         2010.,  2370.,  1840.,  2070.,  4340.,   840.,  1240.,  1390.,
#         2310.,  1050.,  2550.,  1120.,  2230.,   810.,  3190.,  1670.,
#         1970., 13540.,  1880.,  1920.,  3240.,  1550.,  2050.,  2220.,
#         1770.,  2300.,  1790.,  2440.,  1160.,  3400.,  4420.,  1571.,
#         1620.,  1408.,  3040.,  4490.,  1590.,  2450.,  1440.,  1100.,
#         2150.,  1490.,  1030.,   720.,  2020.,  1580.,  1300.,  1630.,
# ...

# %%
a1=df['sqft_living'].sort_values(ascending=True)

# %%
a1
# Out:
# 3778    370.0
# 2919    380.0
# 2416    420.0
# 1219    430.0
# 4184    490.0
#         ...
# 59        NaN
# 60        NaN
# 61        NaN
# 62        NaN
# 63        NaN
# Name: sqft_living, Length: 4600, dtype: float64

# %%
p2=df.sqft_living.mean()

# %%
p2
# Out:
# 2138.9355263157895

# %%
df.sqft_living.fillna(p2,inplace=True)

# %%
df.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot         14
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built         23
# yr_renovated      0
# street            0
# city             57
# statezip          0
# country           0
# dtype: int64

# %%
df['city'].unique()
# Out:
# array(['Shoreline', 'Seattle', 'Kent', 'Bellevue', 'Redmond',
#        'Maple Valley', 'North Bend', nan, 'Snoqualmie', 'Renton',
#        'Auburn', 'Sammamish', 'Kirkland', 'Issaquah', 'Des Moines',
#        'Federal Way', 'Duvall', 'Burien', 'Covington',
#        'Inglewood-Finn Hill', 'Kenmore', 'Carnation', 'Newcastle',
#        'Woodinville', 'Mercer Island', 'Black Diamond', 'Ravensdale',
#        'Bothell', 'Clyde Hill', 'Algona', 'Lake Forest Park', 'Skykomish',
#        'Normandy Park', 'Tukwila', 'Vashon', 'Fall City', 'Yarrow Point',
#        'SeaTac', 'Medina', 'Enumclaw', 'Snoqualmie Pass', 'Pacific',
#        'Beaux Arts Village', 'Preston', 'Milton'], dtype=object)

# %%
d3=df['city'].sort_values(ascending=True)

# %%
s4=df.city.mode()

# %%
s4
# Out:
# 0    Seattle
# Name: city, dtype: object

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
file=df.iloc[:,1:14]

# %%
file
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05         3       1.50       1340.0       NaN     1.5
# 1     2.384000e+06         5       2.50       3650.0       NaN     2.0
# 2     3.420000e+05         3       2.00       1930.0       NaN     1.0
# 3     4.200000e+05         3       2.25       2000.0       NaN     1.0
# 4     5.500000e+05         4       2.50       1940.0       NaN     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05         3       1.75       1510.0    6360.0     1.0
# 4596  5.343333e+05         3       2.50       1460.0    7573.0     2.0
# 4597  4.169042e+05         3       2.50       3010.0    7014.0     2.0
# 4598  2.034000e+05         4       2.00       2090.0    6630.0     1.0
# 4599  2.206000e+05         3       2.50       1490.0    8102.0     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
Q1 = df['bedrooms'].quantile(0.25)
Q3 = df['bedrooms'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 1.0

# %%
print((df['bedrooms'] < (Q1 - 1.5 * IQR)) | (df['bedrooms'] > (Q3 + 1.5 * IQR)))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4595    False
# 4596    False
# 4597    False
# 4598    False
# 4599    False
# Name: bedrooms, Length: 4600, dtype: bool

# %%
filter_file=df[~((file< (Q1 - 1.5 * IQR)) | (file> (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
filter_file
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip, country]
# Index: []

# %%
from scipy import stats
import numpy as np

# %%
zscore=np.abs(stats.zscore(file))

# %%
zscore
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# 0     0.414874  0.441122   0.843204     0.831617       NaN  0.022416
# 1     3.151057  1.759705   0.432802     1.572877       NaN  0.906555
# 2     0.364941  0.441122   0.205201     0.217482       NaN  0.951388
# 3     0.230638  0.441122   0.113800     0.144619       NaN  0.951388
# 4     0.006798  0.659291   0.432802     0.207073       NaN  0.951388
# ...        ...       ...        ...          ...       ...       ...
# 4595  0.423197  0.441122   0.524202     0.654663       NaN  0.951388
# 4596  0.033774  0.441122   0.432802     0.706708       NaN  0.906555
# 4597  0.235968  0.441122   0.432802     0.906697       NaN  0.906555
# 4598  0.603588  0.659291   0.205201     0.050937       NaN  0.951388
# 4599  0.573973  0.441122   0.432802     0.675481       NaN  0.906555
#
#       waterfront      view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
Z=3
np.where(zscore > 3)
# Out:
# (array([   1,    1,    8,  100,  118,  122,  122,  122,  122,  122,  122,
#          123,  164,  227,  234,  241,  252,  252,  252,  252,  272,  291,
#          291,  297,  300,  354,  381,  381,  399,  402,  404,  404,  404,
#          414,  414,  418,  418,  452,  452,  462,  462,  462,  471,  478,
#          478,  492,  518,  524,  534,  535,  535,  548,  575,  581,  581,
#          581,  591,  634,  634,  704,  717,  743,  753,  758,  790,  813,
#          839,  839,  839,  847,  847,  847,  862,  879,  916,  970,  970,
#          979,  995, 1017, 1027, 1048, 1076, 1089, 1100, 1126, 1130, 1130,
#         1132, 1132, 1132, 1133, 1149, 1154, 1159, 1163, 1163, 1171, 1176,
#         1182, 1182, 1209, 1209, 1209, 1223, 1258, 1268, 1272, 1296, 1301,
#         1301, 1302, 1302, 1310, 1330, 1331, 1345, 1353, 1355, 1360, 1386,
#         1417, 1417, 1417, 1422, 1455, 1463, 1463, 1464, 1464, 1467, 1468,
#         1479, 1479, 1500, 1500, 1518, 1518, 1527, 1543, 1567, 1567, 1567,
# ...

# %%
zscore['price'][1567]
# Out:
# 4.383894075803234

# %%
file.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.192793   0.319311     0.418896  0.050673  0.143775
# bedrooms       0.192793  1.000000   0.545920     0.593371  0.068805  0.177895
# bathrooms      0.319311  0.545920   1.000000     0.760341  0.107197  0.486428
# sqft_living    0.418896  0.593371   0.760341     1.000000  0.209360  0.343582
# sqft_lot       0.050673  0.068805   0.107197     0.209360  1.000000  0.003540
# floors         0.143775  0.177895   0.486428     0.343582  0.003540  1.000000
# waterfront     0.131387 -0.003483   0.076232     0.117946  0.017233  0.022024
# view           0.220758  0.111028   0.211960     0.310416  0.074262  0.031211
# condition      0.036660  0.025080  -0.119994    -0.061711  0.000579 -0.275013
# sqft_above     0.311732  0.429573   0.612828     0.772715  0.200430  0.460266
# sqft_basement  0.208591  0.334165   0.298020     0.446954  0.034236 -0.255510
# ...

# %%
sns.pairplot(file)
# Out:
# C:\Users\sange\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sange\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sange\anaconda3\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
pip install seaborn --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
a=file.corr()
plt.figure(figsize=(9,9))
sns.heatmap(a,annot=True,cmap="grey")
# Out:
# <Axes: >

# %%
file['price'].unique()
# Out:
# array([ 313000.    , 2384000.    ,  342000.    , ...,  416904.1667,
#         203400.    ,  220600.    ])

# %%
file1=file[['bedrooms','price','yr_built','condition']]
file1.head()
# Out:
#    bedrooms      price  yr_built  condition
# 0         3   313000.0        55          2
# 1         5  2384000.0        21          4
# 2         3   342000.0        66          3
# 3         3   420000.0        63          3
# 4         4   550000.0        76          3

# %%
from sklearn.preprocessing import LabelEncoder
lable=LabelEncoder()
file['bedrooms']=lable.fit_transform(file['bedrooms'])
file['yr_built']=lable.fit_transform(file['yr_built'])
file['condition']=lable.fit_transform(file['condition'])
file
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05         3       1.50       1340.0       NaN     1.5
# 1     2.384000e+06         5       2.50       3650.0       NaN     2.0
# 2     3.420000e+05         3       2.00       1930.0       NaN     1.0
# 3     4.200000e+05         3       2.25       2000.0       NaN     1.0
# 4     5.500000e+05         4       2.50       1940.0       NaN     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05         3       1.75       1510.0    6360.0     1.0
# 4596  5.343333e+05         3       2.50       1460.0    7573.0     2.0
# 4597  4.169042e+05         3       2.50       3010.0    7014.0     2.0
# 4598  2.034000e+05         4       2.00       2090.0    6630.0     1.0
# 4599  2.206000e+05         3       2.50       1490.0    8102.0     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...
